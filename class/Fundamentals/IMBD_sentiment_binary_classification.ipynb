# %% [markdown]
# It is highly recommended to use a powerful **GPU**, you can use it for free uploading this notebook to [Google Colab](https://colab.research.google.com/notebooks/intro.ipynb).
# <table align="center">
#  <td align="center"><a target="_blank" href="https://colab.research.google.com/github/ezponda/intro_deep_learning/blob/main/class/Fundamentals/IMBD_sentiment_binary_classification.ipynb">
#         <img src="https://colab.research.google.com/img/colab_favicon_256px.png"  width="50" height="50" style="padding-bottom:5px;" />Run in Google Colab</a></td>
#   <td align="center"><a target="_blank" href="https://github.com/ezponda/intro_deep_learning/blob/main/class/Fundamentals/IMBD_sentiment_binary_classification.ipynb">
#         <img src="https://github.githubassets.com/images/modules/logos_page/GitHub-Mark.png"  width="50" height="50" style="padding-bottom:5px;" />View Source on GitHub</a></td>
# </table>

# %% [markdown]
# # Classification Example
#  Two-class classification, or binary classification, may be the most widely applied kind of machine-learning problem. In this example, you’ll learn to classify movie reviews as positive or negative, based on the text content of the reviews.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
tf.random.set_seed(0)

# %% [markdown]
# ## The Dataset: The IMDB dataset
# We’ll work with the IMDB dataset: a set of 50,000 highly polarized reviews from the Internet Movie Database. They’re split into 25,000 reviews for training and 25,000 reviews for testing, each set consisting of 50% negative and 50% positive reviews. The  parameter `num_words` controls how many words different we want to use.

# %%
from tensorflow.keras.datasets import imdb
num_words = 10000
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=num_words)
print(train_data[0])
# Out:
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]

# %%
# Transform word_id to word and reverse
word2int = imdb.get_word_index()
word2int = {w: i+3 for w, i in word2int.items()}
word2int["<PAD>"] = 0
word2int["<START>"] = 1
word2int["<UNK>"] = 2
word2int["<UNUSED>"] = 3
int2word = {i: w for w, i in word2int.items()}
num_words = num_words+3
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1641221/1641221 ━━━━━━━━━━━━━━━━━━━━ 1s 1us/step

# %% [markdown]
# For transforming an id-sequence to a phrase use get_words

# %%
def get_words(sentence, int2word):
    return ' '.join([int2word.get(i,'<UNK>') for i in sentence])
print(get_words(train_data[0], int2word))
print('Sentiment: ', train_labels[0])
# Out:
# <START> this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert <UNK> is an amazing actor and now the same being director <UNK> father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for <UNK> and would recommend it to everyone to watch and the fly <UNK> was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also <UNK> to the two little <UNK> that played the <UNK> of norman and paul they were just brilliant children are often left out of the <UNK> list i think because the stars that play them all grown up are such a big <UNK> for the whole film but these children are amazing and should be <UNK> for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was <UNK> with us all
# Sentiment:  1

# %% [markdown]
# ## Data Preprocessing
#
# You need to convert your raw text to an appropriate input to a sequential model

# %%
def vectorize_text_sentence(text, word2int):
    tokens = text.split(' ')
    tokens_id = [word2int.get(tk,2) for tk in tokens]
    return tokens_id

text = get_words(train_data[0], int2word)
print(text)
print(vectorize_text_sentence(text, word2int))
# Out:
# <START> this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert <UNK> is an amazing actor and now the same being director <UNK> father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for <UNK> and would recommend it to everyone to watch and the fly <UNK> was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also <UNK> to the two little <UNK> that played the <UNK> of norman and paul they were just brilliant children are often left out of the <UNK> list i think because the stars that play them all grown up are such a big <UNK> for the whole film but these children are amazing and should be <UNK> for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was <UNK> with us all
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 2, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 2, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 2, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 2, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 2, 19, 178, 32]

# %% [markdown]
# ### Bag of Words Model BoW
# We are going to use a bag of words model. BoW is a simplifying representation used in natural language processing. In this model, a text (such as a sentence or a document) is represented as the Each key is the word, and each value is the frequency of occurrences of that word in the given text document.
#
# - **Input document**: `"John likes to watch movies Mary likes movies too"`
# - **BoW**: `{'John': 1, 'likes': 2, 'to': 1, 'watch': 1, 'movies': 2, 'Mary': 1, 'too': 1}`
# - **BoW Normalized**: `{'John': 0.11, 'likes': 0.22, 'to': 0.11, 'watch': 0.11, 'movies': 0.22, 'Mary': 0.11, 'too': 0.11}`

# %%
from collections import Counter

def get_bag_of_words(sequence, norm=True):
    word_count = Counter(sequence)
    if norm:
        total = sum(word_count.values())
        word_freq = {w: n / total for w, n in word_count.items()}
        return word_freq
    else:
        return dict(word_count.items())

text_example = "John likes to watch movies Mary likes movies too"
print('text_example', text_example)
text_sequence = text_example.split()
print('text splitted', text_sequence)
bag_of_words = get_bag_of_words(text_sequence)
print('bag_of_words', bag_of_words)
print('bag_of_words norm=False', get_bag_of_words(text_sequence, norm=False))
print(
    'bag_of_words with indexes', {
        word2int[w.lower()]: p
        for w, p in get_bag_of_words(text_sequence, norm=False).items()
    })
# Out:
# text_example John likes to watch movies Mary likes movies too
# text splitted ['John', 'likes', 'to', 'watch', 'movies', 'Mary', 'likes', 'movies', 'too']
# bag_of_words {'John': 0.1111111111111111, 'likes': 0.2222222222222222, 'to': 0.1111111111111111, 'watch': 0.1111111111111111, 'movies': 0.2222222222222222, 'Mary': 0.1111111111111111, 'too': 0.1111111111111111}
# bag_of_words norm=False {'John': 1, 'likes': 2, 'to': 1, 'watch': 1, 'movies': 2, 'Mary': 1, 'too': 1}
# bag_of_words with indexes {308: 1, 1232: 2, 8: 1, 106: 1, 102: 2, 1083: 1, 99: 1}

# %% [markdown]
# ### Document Term Matrix
#
# We need a way to model the documents so that they are all the same length, so that we can use a neural network. For this we are going to use the document term matrix.
# - Every document is a vector with the dimension of the vocabulary.
# - The position i of the vector corresponds to the word with index i.
# - The vector is all zeros except for the BoW word positions, which are filled with the frequency of the corresponding word.
#
#
# For example:
#
# - D1 = "I like movies",  `{'I': 1, 'like': 1, 'movies': 1}`
#
# - D2 = "I dislike movies",  `{'I': 1, 'dislike': 1, 'movies': 1}`
#
# Then the document-term matrix would be:
#
#
#
#    | Doc| I  | like    | dislike   | movies   |
# |---:|:-------------|:-----------|:------|:------|
# | D1 | 1  | 1       | 0   | 1     |
# | D2 | 1  | 0    | 1   | 1     |
#
# $D1 = [1,1,0,1]$
#
# $D2 = [1,0,1,1]$
#
# We convert every BoW to a vector of `dim=num_words` with `vectorize_sequences`

# %%
def vectorize_sequence(sequence, num_words, norm=True):
    vec = np.zeros(num_words)
    bow = get_bag_of_words(sequence, norm)
    for w, freq in bow.items():
        if w < num_words:
            vec[w] = freq
    return vec


def vectorize_sequences(sequences, num_words=num_words, norm=True):
    """Creates an all-zero matrix of shape (len(sequences), num_words)"""
    results = np.zeros((len(sequences), num_words))
    for i, sequence in enumerate(sequences):
        results[i, :] = vectorize_sequence(sequence, num_words, norm)
    return results


x_train = vectorize_sequences(train_data, num_words=num_words)
x_test = vectorize_sequences(test_data, num_words=num_words)
y_train =np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')
x_train.shape, y_train.shape
# Out:
# ((25000, 5003), (25000,))

# %% [markdown]
# ## Define and train a model
#
# Define, compile and fit your NN model
#
# 1. You can use the [Functional API](https://keras.io/guides/functional_api/):
#
# You need to start with an input data entry:
# ```python
#     inputs = keras.Input(shape=(8,))
#     layer_1 = layers.Dense(...)(inputs)
# ```
#
# and the network outputs:
# ```python
# outputs = layers.Dense(...)(previous_layer)
# model = keras.Model(inputs=inputs, outputs=outputs)
# ```
#
# 2. Or you can use [Sequential API](https://keras.io/guides/sequential_model/)
#
# ```python
# model = keras.Sequential(name='example_model')
# model.add(layers.Dense(..., input_shape=(8,))
# model.add(...
# ```
#
# You can introduce regularization methods seen in [Prevent_Overfitting.ipynb](https://github.com/ezponda/intro_deep_learning/blob/main/class/Fundamentals/Prevent_Overfitting.ipynb) like [Dropout layer](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dropout):
#
#
# ```python
# tf.keras.layers.Dropout(
#     rate, noise_shape=None, seed=None, **kwargs
# )
# ```
#
# With Functional API:
# ```python
# next_layer = layers.Dropout(0.4)(prev_layer)
# ```
# With Sequential:
# ```python
# model.add(layers.Dropout(0.4))
# ```
#
# First try with only one hidden layer and see the results.

# %%
model = ...

# %%
# Modelo basico
inputs = tf.keras.Input(shape=(num_words,), name='input_layer')  # entrada
inputs = layers.Dropout(0.5, name='dropout_l3')(inputs)
l_1 = layers.Dense(16, activation='sigmoid')(inputs)
l_1 = layers.Dropout(0.5, name='dropout_l1')(l_1)
l_2 = layers.Dense(32, activation='sigmoid')(l_1)
l_2 = layers.Dropout(0.5, name='dropout_l3')(l_2)

#Salida es binaria -> una capa y tipo sigmoid
outputs = layers.Dense(1, activation='sigmoid')(l_2)


# Model definition
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
es_callback = keras.callbacks.EarlyStopping(
    monitor='val_loss',  # can be 'val_accuracy'
    patience=5,  # if during 5 epochs there is no improvement in `val_loss`, the execution will stop
    restore_best_weights=True,
    verbose=1)

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy'],
)

# , callbacks=[es_callback]
history = model.fit(x_train, y_train, validation_split=0.25, epochs= 50, batch_size=64, callbacks=[es_callback])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-8-728060409.py in <cell line: 0>()
#       5     verbose=1)
#       6
# ----> 7 model.compile(
#       8     optimizer='adam',
#       9     loss='binary_crossentropy',
#
# NameError: name 'model' is not defined

# %%
import matplotlib.pyplot as plt
import pandas as pd
def show_loss_accuracy_evolution(hist):

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Sparse Categorical Crossentropy')
    ax1.plot(hist['epoch'], hist['loss'], label='Train Error')
    ax1.plot(hist['epoch'], hist['val_loss'], label = 'Val Error')
    ax1.grid()
    ax1.legend()

    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Accuracy')
    ax2.plot(hist['epoch'], hist['accuracy'], label='Train Accuracy')
    ax2.plot(hist['epoch'], hist['val_accuracy'], label = 'Val Accuracy')
    ax2.grid()
    ax2.legend()

    plt.show()

hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
show_loss_accuracy_evolution(hist)

# %% [markdown]
# ### Evaluate the model
# You need to obtain a Test Accuracy > 0.85. Try to get more than 0.9!

# %%
results = model.evaluate(x_test, y_test, verbose=1)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8376 - loss: 0.4390
# Test Loss: 0.43940597772598267
# Test Accuracy: 0.8381199836730957

# %%
def show_errors(x_test, model, labels, int2word, n_samples=10):
    preds = 1.0 * (model.predict(x_test).flatten() > 0.5)
    bad_pred_inds = np.where(preds != labels)[0]
    n_samples = min(len(bad_pred_inds), n_samples)
    samples_inds = np.random.choice(bad_pred_inds, n_samples)
    for ind in samples_inds:
        print('Predicted : {0}, real : {1}, lenght: {2}'.format(
            int(preds[ind]), labels[ind], len(test_data[ind])))
        print(get_words(test_data[ind], int2word))
        print()
    return

show_errors(x_test, model, y_test, int2word, n_samples=10)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# Predicted : 1, real : 0.0, lenght: 83
# <START> a female ex cop who was <UNK> out of the force for <UNK> and who could probably beat chuck <UNK> in a fight <UNK> herself out as a private <UNK> her first <UNK> is a worthless <UNK> type it takes half the movie for her to get kicked off the force in the first place lots of great fight choreography but the plot is strictly by the numbers and the acting is as wooden as the dialogue give this one a miss
#
# Predicted : 0, real : 1.0, lenght: 131
# <START> i think dirty dancing was a great movie they tried to make another one <UNK> nights which was good but it was nothing like dirty dancing i would like to see another dirty dancing with the same people without them i think it would be a mess a lot of times movies are made then when they try to add on more they start to change the people an make the movies go down hill i would love to see dirty dancing have another one to see what happened after they were able to be together patrick an jennifer did so well together this movie was made in <UNK> its time to make another one but this time start where it left off an keep the same people in it
#
# Predicted : 0, real : 1.0, lenght: 161
# <START> on seeing this movie i didn't expect much i was <UNK> surprised although the writing was <UNK> as some of the dialog seemed drawn out and contrived the script did have shining moments my favorite line life is like a rich <UNK> an and i'm <UNK> so i can't enjoy it the plot was new and refreshing as opposed to some of the <UNK> more main <UNK> horror that most of us are sadly growing used to i do believe some of the scenes could should have been longer and maybe some <UNK> the <UNK> use of blood was campy but seemed to make sense in the end ah the end the end would have been a little better if they had explained why what happened happened i don't wanna spoil it it might have also added to the movie time which is in the area of it's only an hour long how good could it be answer quite good
#
# Predicted : 0, real : 1.0, lenght: 124
# <START> star rating <UNK> very good okay you could go out for a <UNK> instead avoid at all costs br br the tale of the <UNK> adam mark <UNK> <UNK> and paul tom murphy two <UNK> <UNK> in the <UNK> of <UNK> and their daily about in their meaningless lives searching for the next fix that will make their day along the way they try and <UNK> with close family and friends who they've managed to let down and destroy over the years br br i know a lot of irish people like to drink but it seems some of them have problems with <UNK> too by the looks of this movie i know there is a bit of a drug problem over there like there is in many parts of the world so another humorous take on the subject matter is not an entirely unexpected thing br br i don't recall the last irish movie i saw the film is shot in a style that makes it stand out from any film i've seen lately and judging from that obviously i'm not as <UNK> on their humour as i could be the film is rather funny in certain parts but it's obviously another comedy that isn't afraid to raise near the <UNK> laughs the scene in which the mentally <UNK> boy is <UNK> down the back of an <UNK> is certainly true of what a pair of <UNK> might do to feed their <UNK> but is nonetheless utterly <UNK> and i'm not sure if it was meant as dark humour in any way but it certainly didn't put a smile on my face it's also in <UNK> contrast to their previous actions where they're seen showing their soft side <UNK> a baby to and <UNK> in light of this some may find the ending sad others may see it as just <UNK> br br overall i just failed to see the point to the film i didn't see any motivation in the <UNK> it was telling it just seems to <UNK> along without really involving the audience in any way unlike <UNK> which dealt with similar themes it's an <UNK> effort for the most part that had me on the <UNK> of <UNK> off despite it's very short <UNK> minute running time really no more enjoyable than following two real life <UNK> around for a day
#
# Predicted : 1, real : 0.0, lenght: 145
# <START> <UNK> of white and various <UNK> a beautiful nude random images that is what this little <UNK> short film is br br it's kind of interesting to think how in the early days of film such images could be <UNK> onto film but despite my love of a lot of surreal images and films and a <UNK> with the bizarre this film just didn't do it for me br br i'm not sorry i watched it but if there is any <UNK> meaning in it i don't get it visually it is not that outstanding in my humble opinion as an example of i suppose it would fit in quite well since it seems to <UNK> any <UNK> of logic or reason though i would have <UNK> that it do it in a more visually interesting way br br but to each his own
#
# Predicted : 1, real : 0.0, lenght: 109
# <START> j carol <UNK> and ralph morgan star in a movie about a mad scientist in love with a daughter when his <UNK> are <UNK> he <UNK> the father with a <UNK> disease so that she will be forced to come to him to get a cure br br god this is awful its dull and boring and you'll <UNK> off before the <UNK> gets i was on the <UNK> <UNK> it picks up once things are set in motion but this is one of those old movies better remembered then seen again br br if you must see it come in late br br 4 out of 10

# %% [markdown]
# ### Making predictioins with new data

# %%
reviews = ['the film was really bad and i am very disappointed',
           'The film was very funny entertaining and good we had a great time . brilliant film',
           'this film was just brilliant',
           'the movie is not bad',
           'the movie is not bad I like it'
]
sequences = [vectorize_text_sentence(review.lower(), word2int)
             for review in reviews]

x_pred = vectorize_sequences(sequences, num_words=num_words)
predictions = model.predict(x_pred)
for review, pred in zip(reviews, predictions.flatten()):
    print()
    print(review)
    print('Sentiment: ', np.round(pred, 2))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
#
# the film was really bad and i am very disappointed
# Sentiment:  0.19
#
# The film was very funny entertaining and good we had a great time . brilliant film
# Sentiment:  0.96
#
# this film was just brilliant
# Sentiment:  0.16
#
# the movie is not bad
# Sentiment:  0.01
#
# the movie is not bad I like it
# Sentiment:  0.03

# %%
1.0*(model.predict(x_pred) > 0.5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# array([[0.],
#        [1.],
#        [0.],
#        [0.],
#        [0.]])

# %% [markdown]
# ### Question 1: Repeat the process with unnormalized bag of words, compare results

# %%
x_train = vectorize_sequences(train_data, num_words=num_words, norm=False)
x_test = vectorize_sequences(test_data, num_words=num_words, norm=False)
y_train =np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')
x_train.shape, y_train.shape
# Out:
# ((25000, 10003), (25000,))

# %%
# Modelo basico
inputs = tf.keras.Input(shape=(num_words,), name='input_layer')  # entrada
inputs = layers.Dropout(0.5, name='dropout_l3')(inputs)
l_1 = layers.Dense(16, activation='sigmoid')(inputs)
l_1 = layers.Dropout(0.5, name='dropout_l1')(l_1)
l_2 = layers.Dense(32, activation='sigmoid')(l_1)
l_2 = layers.Dropout(0.5, name='dropout_l3')(l_2)

#Salida es binaria -> una capa y tipo sigmoid
outputs = layers.Dense(1, activation='sigmoid')(l_2)


# Model definition
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
history = model.fit(x_train, y_train, validation_split=0.25, epochs= 10, batch_size=32)
show_loss_accuracy_evolution(hist)
results = model.evaluate(x_test, y_test, verbose=1)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Epoch 1/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.5666 - loss: 0.6873 - val_accuracy: 0.8790 - val_loss: 0.3618
# Epoch 2/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8315 - loss: 0.3973 - val_accuracy: 0.8906 - val_loss: 0.2726
# Epoch 3/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8838 - loss: 0.2917 - val_accuracy: 0.8939 - val_loss: 0.2612
# Epoch 4/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9054 - loss: 0.2486 - val_accuracy: 0.8960 - val_loss: 0.2632
# Epoch 5/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9232 - loss: 0.2097 - val_accuracy: 0.8933 - val_loss: 0.2702
# Epoch 6/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9286 - loss: 0.1942 - val_accuracy: 0.8947 - val_loss: 0.2777
# Epoch 7/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9326 - loss: 0.1747 - val_accuracy: 0.8949 - val_loss: 0.2875
# Epoch 8/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9417 - loss: 0.1595 - val_accuracy: 0.8926 - val_loss: 0.3046
# Epoch 9/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9470 - loss: 0.1463 - val_accuracy: 0.8933 - val_loss: 0.3153
# Epoch 10/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9499 - loss: 0.1360 - val_accuracy: 0.8910 - val_loss: 0.3275
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8803 - loss: 0.3574
# Test Loss: 0.3588830530643463
# Test Accuracy: 0.8785600066184998

# %% [markdown]
# ### Question 2: What happens if you reduce the size of the vocabulary `num_words`, compare results

# %%
num_words = 5000
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=num_words)
print(train_data[0])

word2int = imdb.get_word_index()
word2int = {w: i+3 for w, i in word2int.items()}
word2int["<PAD>"] = 0
word2int["<START>"] = 1
word2int["<UNK>"] = 2
word2int["<UNUSED>"] = 3
int2word = {i: w for w, i in word2int.items()}
num_words = num_words+3

x_train = vectorize_sequences(train_data, num_words=num_words)
x_test = vectorize_sequences(test_data, num_words=num_words)
y_train =np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')
x_train.shape, y_train.shape
# Out:
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 2, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 2, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 2, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 2, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 2, 19, 178, 32]
# ((25000, 5003), (25000,))

# %%
# Modelo basico
inputs = tf.keras.Input(shape=(num_words,), name='input_layer')  # entrada
inputs = layers.Dropout(0.5, name='dropout_l3')(inputs)
l_1 = layers.Dense(16, activation='sigmoid')(inputs)
l_1 = layers.Dropout(0.5, name='dropout_l1')(l_1)
l_2 = layers.Dense(32, activation='sigmoid')(l_1)
l_2 = layers.Dropout(0.5, name='dropout_l3')(l_2)

#Salida es binaria -> una capa y tipo sigmoid
outputs = layers.Dense(1, activation='sigmoid')(l_2)


# Model definition
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
history = model.fit(x_train, y_train, validation_split=0.25, epochs= 50, batch_size=16)
show_loss_accuracy_evolution(hist)
results = model.evaluate(x_test, y_test, verbose=1)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Epoch 1/50
# 1172/1172 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.7640 - loss: 0.4805 - val_accuracy: 0.8616 - val_loss: 0.3817
# Epoch 2/50
# 1172/1172 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7689 - loss: 0.4711 - val_accuracy: 0.8614 - val_loss: 0.3796
# Epoch 3/50
# 1172/1172 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.
50
# 1172/1172 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8233 - loss: 0.3825 - val_accuracy: 0.8746 - val_loss: 0.3127
# Epoch 36/50
# 1172/1172 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8267 - loss: 0.3787 - val_accuracy: 0.8762 - val_loss: 0.3147
# Epoch 37/50
# 1172/1172 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8222 - loss: 0.3894 - val_accuracy: 0.8774 - val_loss: 0.3145
# Epoch 38/50
# 1172/1172 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8288 - loss: 0.3791 - val_accuracy: 0.8755 - val_loss: 0.3101
# Epoch 39/50
# 1172/1172 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8229 - loss: 0.3813 - val_accuracy: 0.8752 - val_loss: 0.3084
# Epoch 40/50
# 1172/1172 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8302 - loss: 0.3770 - val_accuracy: 0.8778 - val_loss: 0.3101
# Epoch 41/50
# 1172/1172 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8303 - loss: 0.3745 - val_accuracy: 0.8770 - val_loss: 0.3084
# Epoch 42/50
# 1172/1172 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8335 - loss: 0.3744 - val_accuracy: 0.8773 - val_loss: 0.3080
# Epoch 43/50
# 1172/1172 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8298 - loss: 0.3762 - val_accuracy: 0.8765 - val_loss: 0.3076
# Epoch 44/50
# 1172/1172 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8319 - loss: 0.3714 - val_accuracy: 0.8762 - val_loss: 0.3074
# Epoch 45/50
# 1172/1172 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8347 - loss: 0.3655 - val_accuracy: 0.8773 - val_loss: 0.3033
# Epoch 46/50
# 1172/1172 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8366 - loss: 0.3696 - val_accuracy: 0.8779 - val_loss: 0.3040
# Epoch 47/50
# 1172/1172 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8372 - loss: 0.3654 - val_accuracy: 0.8770 - val_loss: 0.3048
# Epoch 48/50
# 1172/1172 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8383 - loss: 0.3631 - val_accuracy: 0.8792 - val_loss: 0.3020
# Epoch 49/50
# 1172/1172 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8349 - loss: 0.3688 - val_accuracy: 0.8792 - val_loss: 0.3027
# Epoch 50/50
# 1172/1172 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8364 - loss: 0.3596 - val_accuracy: 0.8773 - val_loss: 0.3010
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8781 - loss: 0.3076
# Test Loss: 0.3070136308670044
# Test Accuracy: 0.8786799907684326

# %%
reviews = [
    'the film was really bad and i am very disappointed',
    'The film was very funny entertaining and good we had a great time . brilliant film',
    'this film was just brilliant', 'the movie is not bad',
    'the movie is not bad I like it'
]
sequences = [
    vectorize_text_sentence(review.lower(), word2int) for review in reviews
]

x_pred = vectorize_sequences(sequences, num_words=num_words)
predictions = model.predict(x_pred)
for review, pred in zip(reviews, predictions.flatten()):
    print()
    print(review)
    print('Sentiment: ', np.round(pred, 2))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
#
# the film was really bad and i am very disappointed
# Sentiment:  0.51
#
# The film was very funny entertaining and good we had a great time . brilliant film
# Sentiment:  0.53
#
# this film was just brilliant
# Sentiment:  0.51
#
# the movie is not bad
# Sentiment:  0.5
#
# the movie is not bad I like it
# Sentiment:  0.5

# %% [markdown]
# ### Compare with other ML algorithms

# %%
from sklearn.linear_model import LogisticRegression
clr = LogisticRegression()
clr.fit(x_train, y_train)
val_acc = clr.score(x_test, y_test)
print('Test Accuracy: {}'.format(val_acc))
# Out:
# Test Accuracy: 0.71792

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(max_depth=5, n_jobs=-1)
rfc.fit(x_train, y_train)
val_acc = rfc.score(x_test, y_test)
print('Test Accuracy: {}'.format(val_acc))
# Out:
# Test Accuracy: 0.81096

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_jobs=-1)
rfc.fit(x_train, y_train)
val_acc = rfc.score(x_test, y_test)
print('Test Accuracy: {}'.format(val_acc))
# Out:
# Test Accuracy: 0.84216

# %%
reviews = []
# training reviews
for ind in range(len(train_data)):
    sentence = train_data[ind]
    sentence_text = get_words(train_data[ind], int2word)
    reviews.append(sentence_text)
print('First training review: ', reviews[0])
# Out:
# First training review:  <START> this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert <UNK> is an amazing actor and now the same being director <UNK> father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for <UNK> and would recommend it to everyone to watch and the fly <UNK> was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also <UNK> to the two little <UNK> that played the <UNK> of norman and paul they were just brilliant children are often left out of the <UNK> list i think because the stars that play them all grown up are such a big <UNK> for the whole film but these children are amazing and should be <UNK> for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was <UNK> with us all
